# %%
#RESPUESTA 1: CONECTARSE AL ENLACE
import pandas as pd
from IPython.display import display
import requests
import time
r=requests.get("https://api.stackexchange.com/2.2/search?order=desc&sort=activity&intitle=perl&site=stackoverflow").json()

#RESPUESTA 2: NUMERO DE RESPUESTAS CONTESTADAS Y NO CONTESTADAS
df=pd.DataFrame(r["items"])
c=df.apply(lambda x: x["is_answered"] == True, axis=1).sum()
nc=len(df.index)-c
print("El numero de respuestas contestadas son: ",c)
print("El numero de respuestas no contestadas son: ",nc)

#RESPUESTA 3: RESPUESTA CON MENOR NUMERO DE VISITAS
min_v= df[(df.view_count==min(df["view_count"]))]
print("\n\nLas menores visitas tienen:", min(df["view_count"]))
print("Correspondientes a los siguientes registros.")
display(min_v)

#RESPUESTA 4: OBTENER RESPUESTA MAS VIEJA Y MAS ACTUAL
#RESPUESTA MAS VIEJA
vieja=min(df["creation_date"])
print("\n\nLa respuesta mas vieja corresponde a la fecha: ",time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(vieja)))
print("Y tiene el siguiente registro.")
display(df[(df.creation_date==min(df["creation_date"]))])

#RESPUESTA MAS ACTUAL
actual=max(df["creation_date"])
print("\n\nLa respuesta mas actual corresponde a la fecha: ",time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(actual)))
print("Y tiene el siguiente registro.")
display(df[(df.creation_date==max(df["creation_date"]))])

#RESPUESTA 5: RESPUESTA DEL OWNER CON MAYOR REPUTACION
df1=pd.json_normalize(df["owner"])
index = df1[df1['reputation']==max(df1["reputation"])].index.tolist()
index=int(index[0])
print("\n\nLa mayor reputacion del owner es: ",max(df1["reputation"]))
print("Y la respuesta correspondiente es la siguiente.")
display(df[index:index+1])
# Out:
# El numero de respuestas contestadas son:  23
# El numero de respuestas no contestadas son:  7
#
#
# Las menores visitas tienen: 27
# Correspondientes a los siguientes registros.
#                     tags                                              owner  \
# 2  [api, perl, mikrotik]  {'reputation': 1, 'user_id': 19047480, 'user_t...
#
#    is_answered  view_count  closed_date  answer_count  score  \
# 2        False          27          NaN             0     -1
#
#    last_activity_date  creation_date  last_edit_date  question_id  \
# 2          1651857121     1651791013    1.651792e+09     72134387
#
#                                                 link closed_reason  \
# 2  https://stackoverflow.com/questions/72134387/d...           NaN
#
#                                                title content_license  \
# 2  Does anyone know how to enable mikrotik router...    CC BY-SA 4.0
#
#    accepted_answer_id  protected_date
# 2                 NaN             NaN
# La respuesta mas vieja corresponde a la fecha:  2010-03-23 06:27:18
# Y tiene el siguiente registro.
#               tags                                              owner  \
# 29  [perl, locale]  {'reputation': 12140, 'user_id': 253944, 'user...
#
#     is_answered  view_count  closed_date  answer_count  score  \
# 29         True      655065          NaN            46    716
#
#     last_activity_date  creation_date  last_edit_date  question_id  \
# 29          1651487270     1269347238    1.607106e+09      2499794
#
#                                                  link closed_reason  \
# 29  https://stackoverflow.com/questions/2499794/ho...           NaN
#
#                                             title content_license  \
# 29  How to fix a locale setting warning from Perl    CC BY-SA 4.0
#
#     accepted_answer_id  protected_date
# 29           2510548.0    1.537628e+09
# La respuesta mas actual corresponde a la fecha:  2022-05-06 11:10:28
# Y tiene el siguiente registro.
#                     tags                                              owner  \
# 3  [regex, perl, printf]  {'reputation': 1076, 'user_id': 994486, 'user_...
#
#    is_answered  view_count  closed_date  answer_count  score  \
# 3        False          33          NaN             1     -1
#
#    last_activity_date  creation_date  last_edit_date  question_id  \
# 3          1651855813     1651853428             NaN     72144503
#
#                                                 link closed_reason  \
# 3  https://stackoverflow.com/questions/72144503/c...           NaN
#
#                                                title content_license  \
# 3  Convert Json string literals to utf8 character...    CC BY-SA 4.0
#
#    accepted_answer_id  protected_date
# 3                 NaN             NaN
# La mayor reputacion del owner es:  22628.0
# Y la respuesta correspondiente es la siguiente.
#                                  tags  \
# 26  [python, ruby, perl, bash, shell]
#
#                                                 owner  is_answered  \
# 26  {'reputation': 22628, 'user_id': 336455, 'user...         True
#
#     view_count   closed_date  answer_count  score  last_activity_date  \
# 26       65993  1.368215e+09            12    346          1651518928
#
#     creation_date  last_edit_date  question_id  \
# 26     1283531098    1.651420e+09      3637668
#
#                                                  link     closed_reason  \
# 26  https://stackoverflow.com/questions/3637668/wh...  not constructive
#
#                                                 title content_license  \
# 26  Why are scripting languages (e.g. Perl, Python...             NaN
#
#     accepted_answer_id  protected_date
# 26           3640403.0    1.346935e+09
